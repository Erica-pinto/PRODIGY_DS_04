# %%
##############TASK04 

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
twitterdata= pd.read_csv('C:/Users/erica/Desktop/twits.csv')

# %%
twitterdata.head()
# Out:
#      ID       Entity Sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                Tweet
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
# Drop rows with missing values
twitterdata.dropna(inplace=True)

# %%
# Drop duplicates
twitterdata.drop_duplicates(inplace=True)

# %%
# Check the shape of the dataframe
print("Shape of the dataframe:", twitterdata.shape)
# Out:
# Shape of the dataframe: (71655, 4)

# %%
# Check for null values
print("Null values:\n", twitterdata.isnull().sum())
# Out:
# Null values:
#  ID           0
# Entity       0
# Sentiment    0
# Tweet        0
# dtype: int64

# %%
# Check for duplicate rows
print("Number of duplicate rows:", twitterdata.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# Get value counts of sentiment
sentiment_counts = twitterdata['Sentiment'].value_counts()
print("Sentiment counts:\n", sentiment_counts)
# Out:
# Sentiment counts:
#  Sentiment
# Negative      21698
# Positive      19713
# Neutral       17707
# Irrelevant    12537
# Name: count, dtype: int64

# %%
# Define custom colors for the bars
custom_colors = ['coral', 'lightgreen', 'tan', 'violet']

# Visualize sentiment distribution with custom colors
plt.figure(figsize=(8, 4))
sentiment_counts.plot(kind='bar', color=custom_colors)
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.xticks(rotation=0)
plt.show()

# %%
# Filter data for Microsoft
filter_data = twitterdata[twitterdata['Entity'].str.contains('Microsoft', case=False)]

# %%
# Get sentiment counts for Microsoft
filter_sentiment_counts = filter_data['Sentiment'].value_counts()
print("Sentiment counts for Microsoft:\n", filter_sentiment_counts)
# Out:
# Sentiment counts for Microsoft:
#  Sentiment
# Neutral       816
# Negative      748
# Positive      573
# Irrelevant    167
# Name: count, dtype: int64

# %%
# Visualize sentiment distribution for Microsoft using a donut chart
plt.figure(figsize=(6, 6))

# Outer pie chart (larger)
plt.pie(brand_sentiment_counts, labels=brand_sentiment_counts.index, autopct='%1.1f%%', startangle=140,
        colors=['lightcoral', 'lightskyblue', 'lightgreen', 'lavender'], wedgeprops=dict(width=0.3, edgecolor='w'))

# Inner pie chart (smaller, white to create the donut effect)
plt.pie([1], colors=['white'], radius=0.2)

plt.title('Sentiment Distribution for Microsoft')
plt.show()

# %% [markdown]
# 1. Data Loading and Inspection:
# Loaded the Twitter entity sentiment analysis dataset.
# Inspected the dataset structure, statistics, and data types.
# Checked for missing values and addressed any data inconsistencies.
#
# 2. Sentiment Analysis:
# Utilized Natural Language Processing (NLP) techniques to analyze sentiment patterns in social media data.
# Applied sentiment analysis algorithms to quantify public opinion and attitudes towards specific topics or brands.
# Extracted sentiment scores or labels to categorize tweets as positive, negative, or neutral.
#
# 3. Visualization:
# Visualized sentiment trends over time using line charts or time series analysis.
# Employed word clouds or bar charts to highlight frequently mentioned keywords or sentiments.
# Created sentiment distribution plots to illustrate the distribution of positive, negative, and neutral sentiments.
# This analysis provides valuable insights into public sentiment and attitudes on social media, aiding in brand perception management and decision-making processes.
